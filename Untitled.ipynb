# %%
import numpy as np

def discretisation(n):
    M = np.array(np.arange(0, 1, 1/n) for k in range(n))
    print(M)

print(discretisation(3))
# Out:
# <generator object discretisation.<locals>.<genexpr> at 0x1104910b0>
# None

# %%
    print([np.arange(0, 1, 1/3)] for k in range(3))
# Out:
# <generator object <genexpr> at 0x110491430>
